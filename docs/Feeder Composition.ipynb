# %% [markdown]
# The feeder composition data provides information about the fractional load arising from each building type on different kinds of feeders in various regions.

# %%
import feeder.composition as lm
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Examples

# %% [markdown]
# This loads the NERC default feeder composition for residential feeders.

# %%
lm.feeder_composition(select={"region":"nerc","feeder_type":"residential"})
# Out:
#                                            floorarea_per_building  \
# region feeder_type building_type
# nerc   residential home                                      1500
#                    college                                 500000
#                    grocery                                  45000
#                    health                                   10000
#                    large_office                            700000
#                    lodging                                  50000
#                    miscellaneous                            10000
#                    refrigerated_warehouse                   50000
#                    restaurant                                5000
#                    retail                                   20000
#                    school                                  100000
#                    small_office                             50000
#                    warehouse                                50000
#
#                                            number_of_buildings  floorarea  \
# region feeder_type building_type
# nerc   residential home                                   4000    6000000
#                    college                                   0          0
#                    grocery                                   2      90000
#                    health                                    4      40000
#                    large_office                              0          0
#                    lodging                                   0          0
#                    miscellaneous                             1      10000
#                    refrigerated_warehouse                    0          0
#                    restaurant                               20     100000
#                    retail                                   30     600000
#                    school                                    4     400000
#                    small_office                              0          0
#                    warehouse                                 3     150000
#
#                                            composition
# region feeder_type building_type
# nerc   residential home                           0.81
#                    college                        0.00
#                    grocery                        0.01
#                    health                         0.01
#                    large_office                   0.00
#                    lodging                        0.00
#                    miscellaneous                  0.00
#                    refrigerated_warehouse         0.00
#                    restaurant                     0.01
#                    retail                         0.08
#                    school                         0.05
#                    small_office                   0.00
#                    warehouse                      0.02

# %% [markdown]
# This loads the NERC default feeder composition for commercial feeders.

# %%
lm.feeder_composition(select={"region":"nerc","feeder_type":"commercial"})
# Out:
#                                            floorarea_per_building  \
# region feeder_type building_type
# nerc   commercial  home                                      1500
#                    college                                 500000
#                    grocery                                  45000
#                    health                                   10000
#                    large_office                            700000
#                    lodging                                  50000
#                    miscellaneous                            10000
#                    refrigerated_warehouse                   50000
#                    restaurant                                5000
#                    retail                                   20000
#                    school                                  100000
#                    small_office                             50000
#                    warehouse                                50000
#
#                                            number_of_buildings  floorarea  \
# region feeder_type building_type
# nerc   commercial  home                                      0          0
#                    college                                   0          0
#                    grocery                                   2      90000
#                    health                                    4      40000
#                    large_office                              6    4200000
#                    lodging                                  20    1000000
#                    miscellaneous                             1      10000
#                    refrigerated_warehouse                    0          0
#                    restaurant                               25     125000
#                    retail                                   30     600000
#                    school                                    0          0
#                    small_office                              2     100000
#                    warehouse                                 0          0
#
#                                            composition
# region feeder_type building_type
# nerc   commercial  home                           0.00
#                    college                        0.00
#                    grocery                        0.01
#                    health                         0.01
#                    large_office                   0.68
#                    lodging                        0.16
#                    miscellaneous                  0.00
#                    refrigerated_warehouse         0.00
#                    restaurant                     0.02
#                    retail                         0.10
#                    school                         0.00
#                    small_office                   0.02
#                    warehouse                      0.00

# %% [markdown]
# This loads the NERC default feeder composition for mixed feeders.

# %%
lm.feeder_composition(select={"region":"nerc","feeder_type":"mixed"})
# Out:
#                                            floorarea_per_building  \
# region feeder_type building_type
# nerc   mixed       home                                      1500
#                    college                                 500000
#                    grocery                                  45000
#                    health                                   10000
#                    large_office                            700000
#                    lodging                                  50000
#                    miscellaneous                            10000
#                    refrigerated_warehouse                   50000
#                    restaurant                                5000
#                    retail                                   20000
#                    school                                  100000
#                    small_office                             50000
#                    warehouse                                50000
#
#                                            number_of_buildings  floorarea  \
# region feeder_type building_type
# nerc   mixed       home                                   2000    3000000
#                    college                                   0          0
#                    grocery                                   3     135000
#                    health                                    6      60000
#                    large_office                              0          0
#                    lodging                                   6     300000
#                    miscellaneous                             2      20000
#                    refrigerated_warehouse                    2     100000
#                    restaurant                               40     200000
#                    retail                                   40     800000
#                    school                                    4     400000
#                    small_office                             12     600000
#                    warehouse                                 8     400000
#
#                                            composition
# region feeder_type building_type
# nerc   mixed       home                           0.50
#                    college                        0.00
#                    grocery                        0.02
#                    health                         0.01
#                    large_office                   0.00
#                    lodging                        0.05
#                    miscellaneous                  0.00
#                    refrigerated_warehouse         0.02
#                    restaurant                     0.03
#                    retail                         0.13
#                    school                         0.07
#                    small_office                   0.10
#                    warehouse                      0.07

# %% [markdown]
# This loads the NERC default feeder composition for rural feeders.

# %%
lm.feeder_composition(select={"region":"nerc","feeder_type":"rural"})
# Out:
#                                            floorarea_per_building  \
# region feeder_type building_type
# nerc   rural       home                                      1500
#                    college                                 500000
#                    grocery                                  45000
#                    health                                   10000
#                    large_office                            700000
#                    lodging                                  50000
#                    miscellaneous                            10000
#                    refrigerated_warehouse                   50000
#                    restaurant                                5000
#                    retail                                   20000
#                    school                                  100000
#                    small_office                             50000
#                    warehouse                                50000
#
#                                            number_of_buildings  floorarea  \
# region feeder_type building_type
# nerc   rural       home                                    400     600000
#                    college                                   0          0
#                    grocery                                   1      45000
#                    health                                    0          0
#                    large_office                              0          0
#                    lodging                                   1      50000
#                    miscellaneous                             0          0
#                    refrigerated_warehouse                    0          0
#                    restaurant                                5      25000
#                    retail                                    3      60000
#                    school                                    1     100000
#                    small_office                              0          0
#                    warehouse                                10     500000
#
#                                            composition
# region feeder_type building_type
# nerc   rural       home                           0.43
#                    college                        0.00
#                    grocery                        0.03
#                    health                         0.00
#                    large_office                   0.00
#                    lodging                        0.04
#                    miscellaneous                  0.00
#                    refrigerated_warehouse         0.00
#                    restaurant                     0.02
#                    retail                         0.04
#                    school                         0.07
#                    small_office                   0.00
#                    warehouse                      0.36
